# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import yfinance as yf

# %%
data = yf.download(
    "AAPL", "2020-01-01", "2025-03-18", group_by="ticker", rounding=True
).set_index(0)[]
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Ticker       AAPL
# Price        Open   High    Low  Close     Volume
# Date
# 2020-01-02  71.72  72.78  71.47  72.72  135480400
# 2020-01-03  71.94  72.77  71.78  72.01  146322800
# 2020-01-06  71.13  72.62  70.88  72.58  118387200
# 2020-01-07  72.59  72.85  72.02  72.24  108872000
# 2020-01-08  71.94  73.71  71.94  73.40  132079200

# %%
data["Close"].plot()

data["Volume"].plot()

data["returns"] = data["Close"].pct_change()
data["returns"].plot()

data["cum_returns"] = (1 + data["returns"]).cumprod()
data["cum_returns"].plot()

data["moving_avg"] = data["Close"].rolling(window=5).mean()
data["moving_avg"].plot()
plt.show()
